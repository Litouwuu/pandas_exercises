# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('C:/Users/Wu yusen/Documents/PandasExerciseFile/chipotle.tsv',sep='\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
chipo.shape[0]
# Out:
# 4622

# %%
# Solution 2
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
print(chipo.shape[1])
len(chipo.columns)
# Out:
# 5
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
c = chipo.groupby('item_name').sum()
c = c.sort_values('quantity',ascending=False)
c.iloc[0].name
# Out:
# 'Chicken Bowl'

# %%
c.head()
# Out:
#                      order_id  quantity
# item_name
# Chicken Bowl           713926       761
# Chicken Burrito        497303       591
# Chips and Guacamole    449959       506
# Steak Burrito          328437       386
# Canned Soft Drink      304753       351

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
c['quantity'][0]
# Out:
# 761

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
o = chipo.groupby('choice_description').sum()
o = o.sort_values('quantity',ascending=False)
maxdescription = o.index[0]
maxdescription
s = chipo.loc[chipo['choice_description']==maxdescription]
s['item_name'].unique()
# Out:
# array(['Canned Soda', '6 Pack Soft Drink', 'Canned Soft Drink'],
#       dtype=object)

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo['quantity'].sum()
# Out:
# 4972

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo = pd.read_csv(url,sep='\t')
tofloat = lambda x: float(x[1:])
chipo.item_price = chipo.item_price.apply(tofloat)

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo.head()
totalrevenue = (chipo['quantity'] * chipo['item_price']).sum()
print("The total revenue is $"+ str(np.round(totalrevenue,2)))
# Out:
# The total revenue is $39237.02
# 39237.02

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
chipo.head()
len(chipo.order_id.unique())
# Out:
# 1834

# %%
chipo.order_id.value_counts().count()
# Out:
# 1834

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1
ordernum = chipo.order_id.value_counts().count()
TotalRevenue = (chipo.quantity* chipo.item_price).sum()
AverRev = TotalRevenue/ordernum
np.round(AverRev,2)
# Out:
# 21.39

# %%
# Solution 2
chipo['revenue'] = chipo['quantity'] * chipo['item_price']
chipo.groupby('order_id').sum().mean()
# Out:
# quantity       2.711014
# item_price    18.811429
# revenue       21.394231
# dtype: float64

# %%
chipo.groupby('order_id').sum()
# Out:
#           quantity  item_price  revenue
# order_id
# 1                4       11.56    11.56
# 2                2       16.98    33.96
# 3                2       12.67    12.67
# 4                2       21.00    21.00
# 5                2       13.70    13.70
# 6                2       17.50    17.50
# 7                2       15.70    15.70
# 8                2       10.88    10.88
# 9                3       10.67    12.85
# 10               2       13.20    13.20
# 11               2       12.38    12.38
# 12               2       14.37    14.37
# 13               2       10.88    10.88
# 14               2       10.08    10.08
# 15               2       10.88    10.88
# 16               2       10.68    10.68
# 17               2       10.08    10.08
# 18               4       24.90    24.90
# 19               2       13.90    13.90
# 20               4       36.20    36.20
# 21               3       23.36    23.36
# 22               2       12.98    12.98
# ...

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
chipo.loc[chipo['item_name'] == 'Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# 110         49         1  Chicken Bowl
# 123         54         1  Chicken Bowl
# 138         62         1  Chicken Bowl
# 140         63         1  Chicken Bowl
# 142         64         1  Chicken Bowl
# 154         70         2  Chicken Bowl
# 160         73         1  Chicken Bowl
# 176         79         1  Chicken Bowl
# 182         82         1  Chicken Bowl
# 193         86         1  Chicken Bowl
# 199         89         1  Chicken Bowl
# 206         92         1  Chicken Bowl
# 209         93         1  Chicken Bowl
# 211         93         1  Chicken Bowl
# ...

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo = pd.read_csv(url,sep='\t')
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo.choice_description.fillna('None',inplace=True)
chipo['Name&Description'] = chipo.item_name + chipo.choice_description

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                               None     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                               None     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#                                     Name&Description
# 0                   Chips and Fresh Tomato SalsaNone
# 1                                   Izze[Clementine]
# 2                            Nantucket Nectar[Apple]
# ...

# %%
itemsCount = chipo['Name&Description'].value_counts().count()
itemsCount
# Out:
# 1871

# %%
chipo.choice_description.value_counts().count()
# Out:
# 1044
